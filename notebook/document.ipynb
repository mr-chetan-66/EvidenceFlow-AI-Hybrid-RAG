# %%
from langchain_core.documents import Document

# %%
doc=Document(page_content="My name is Chetan and I am learning RAG from Krish Naik Video crash course",metadata={
    "page":1,
    "date_created":"2026-08-01",
    "course":"Krish Naik",
})
doc
# Out:
# Document(metadata={'page': 1, 'date_created': '2026-08-01', 'course': 'Krish Naik'}, page_content='My name is Chetan and I am learning RAG from Krish Naik Video crash course')

# %%
import os
os.makedirs("../data/text_file",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
from langchain_community.document_loaders import TextLoader

# %%
loader=TextLoader("../data/text_files/python_intro.txt")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import DirectoryLoader,TextLoader
dic_load=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", #pattern to match files
    loader_cls=TextLoader,
    loader_kwargs={"encoding":'utf-8'},
    show_progress=False
)

print(dic_load.load())
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '), Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader,DirectoryLoader

loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf",
    loader_cls=PyPDFLoader,
    show_progress=False
)

document=loader.load()
print(document)
# Out:
# [Document(metadata={'producer': 'pdfme (https://pdfme.com/)', 'creator': 'pdfme (https://pdfme.com/)', 'creationdate': '2026-08-07T12:34:51+00:00', 'moddate': '2026-08-07T12:34:51+00:00', 'author': 'pdfme (https://pdfme.com/)', 'keywords': '', 'subject': '', 'title': '', 'source': '..\\data\\pdf\\AWS cloud practitioner.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='AWS Training & Certification\n\n\nMichelle Vaz\nDirector, AWS Training & Certification \n\n\n\nAWS Cloud Practitioner\nEssentials\nCompleted: August 05, 2026\nCompletion Certificate\nAwarded to\nChetan Awari'), Document(metadata={'producer': 'Microsoft® Word 2021', 'creator': 'Microsoft® Word 2021', 'creationdate': '2026-06-19T12:09:50+05:30', 'author': 'Chetan Awari', 'moddate': '2026-06-19T12:09:50+05:30', 'source': '..\\data\\pdf\\Chetan_Awari_Resume.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content="CHETAN AW ARI \nchetanawari2002@gmail.com | github.com/mr-chetan-66 | linkedin.com/in/chetan-awari/ | leetcode.com/u/Chetan_Awari/  \nPortfolio: https://portfolio-drab-omega-x8ptxtrdrd.vercel.app/ \nEDUCATION \nG. H. Raisoni College of Engineering | Nagpur, India                                                                                        Nov 2022 – Jul 2026        \nB. Tech – Computer Science & Engineering (Cyber Security) | CGP A: 9.23 \nTECHNICAL SKILLS \nProgramming Languages: Java, Python, C, Kotlin, C++, SQL, JavaScript \nFrameworks & Libraries: React.js, Node.js, FastAPI, Jetpack Compose, Tailwind CSS \nCloud & Platforms: AWS (EC2, S3), Firebase, Oracle XE, PostgreSQL, Docker \nDevelopment Tools: Android Studio, VS Code, GitHub, Splunk \nCore CS Subject: Data Structures & Algorithms, OOP, Operating Systems, DBMS, Computer Networks  \nEXPERIENCE \nSoftware Developer Intern | Capgemini | Bangalore, India | (Link)                                        Jan 2026 – Apr 2026 \n• Developed and tested scalable backend services using Java and Python on AWS, following clean architecture principles to \nensure maintainable, production-ready code. \n• Applied cloud deployment strategies (EC2, S3) to personal and team projects, gaining hands -on experience with enterprise-\ngrade infrastructure. \n• Consistently delivered daily progress within team workflows, developing professional discipline around code reviews, \ndocumentation, and cross-team communication. \n \nFull Stack Web/App Development Intern | ANORG Technologies | (Link)                                                                Jun 2025 – Nov 2025 \n• Contributed to frontend and backend tasks across 3+ active projects, integrating REST APIs and collaborating via Git -based \nworkflows including branching, PR reviews, and task tracking. \n• Observed and documented senior engineers' architecture decisions for a multi -service deployment, improving personal \nunderstanding of system design trade-offs. \n• Maintained 100% daily reporting cadence, demonstrating accountability and structured communication in a remote corporate \nenvironment. \n \nSoftware Development Intern | Center of Excellence (AIML), GHRCE | (Link)                                                 Dec 2024 – Jan 2025 \n• Built an IoT-based smart medicine dispenser using Arduino, ESP32, Firebase, and Android; improved medication scheduling \nefficiency by 66% through QR-based secure authentication. \n• Optimized the Android app for low-resource devices, reducing average response time by 40% through targeted performance \nprofiling and UI rendering improvements. \nPROJECT \nDECAID: Decentralized Academic Identity & Credential Risk Assessment System \nTechnologies: React, Node.js, Express, Python (FastAPI), PostgreSQL, Ethereum, Pinata, IPFS| (GitHub) \n• Built a full-stack decentralized platform for tamper-proof academic credential verification using Ethereum smart contracts \nand IPFS-based distributed storage. \n• Implemented Zero-Knowledge Proof (ZKP) verification to enable privacy-preserving,  ...
